# %%
import numpy as np
import pandas as pd
import re

from urllib.request import urlopen
from bs4 import BeautifulSoup, Comment
import pandas as pd

# %%
# url that we are scraping
url = "http://www.basketball-reference.com/players/d/duncati01.html"

# this is the html from the given url
html = urlopen(url)
soup = BeautifulSoup(html,'lxml')
# Out:
# /Users/rcroke/anaconda/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /Users/rcroke/anaconda/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
column_headers = [th.getText() for th in 
                  soup.findAll('tr', limit=2)[0].findAll('th')]
column_headers

# %%
def get_player_df():
    player_df1 = create_player_dataframe()
    
    #for player in player_df1['BR_player_id']:
    #    player_df1 = _get_player_meta_data(player_df1.copy(),player)
        
    return player_df1

def create_player_dataframe():
    '''
    method for creating all player's in BR player index,
    https://www.basketball-reference.com/players/a/ e.g.
    '''
    
    from string import ascii_lowercase

    # make pandas dataframe for all player info
    player_df = pd.DataFrame(columns=["Player","BR_player_id","From","To",
                                      "Pos","Ht","Wt","Birth Date","College",
                                      "active","shoots","draft_team","pick_order",
                                      "draft_year_type"])

    j = 0
    for letter in ascii_lowercase:

        if letter == "x":
            continue

        url = "http://www.basketball-reference.com/players/"+str(letter)+"/"
        html = urlopen(url)
        soup = BeautifulSoup(html,'lxml')
        player_table = soup.select("#players")

        for i,row in enumerate(player_table[0].find_all("tr")):

            player_info = []

            # skip metadata
            if i == 0:
                continue

            player_info.append(row.find_all("th")[0].text)
            BR_player_id = row.find_all("th")[0]['data-append-csv']
            player_info.append(BR_player_id)

            for row2 in row.find_all("td"):
                player_info.append(row2.text)

            if "<strong>" in str(row.find_all("th")[0]):
                player_info.append(int(1))
            else:
                player_info.append(int(0))
            
            cols_to_fill = ["Player","BR_player_id","From","To",
                            "Pos","Ht","Wt","Birth Date","College",
                            "active"]

            player_df.loc[j,cols_to_fill] = player_info
            player_df = _get_player_meta_data(player_df,letter,BR_player_id)
            
            j+=1
    
            

    return player_df

def _get_player_meta_data(df,letter,BR_player_id):
    temp_player_df = df.copy()
    BR_player_id = BR_player_id
    player_index = temp_player_df[temp_player_df['BR_player_id'] == BR_player_id].index[0]
    
    url = "https://www.basketball-reference.com/players/"+str(BR_player_id)[0]+"/"+BR_player_id+".html"

    try:
        html = urlopen(url)
    except HTTPError:
        print(url)
        return temp_player_df
    
    soup = BeautifulSoup(html,'lxml')

    # find player info by div id
    meta_data = soup.find("div", {"id": "meta"})

    # don't need this 
    #height = meta_data.find('span',attrs={'itemprop' : 'height'}).text
    #weight = meta_data.find('span',attrs={'itemprop' : 'weight'}).text
    #DOB = meta_data.find('span',attrs={'itemprop' : 'birthDate'}).text.strip()

    par_meta = meta_data.find_all('p')

    for val in par_meta:
        to_parse = val.text

        if "Shoots" in to_parse:
            shoots = "".join(to_parse.split('Shoots:')[1])
            shoots = shoots.strip()
            temp_player_df.loc[player_index,'shoots'] = shoots
        if "Position" in to_parse:
            position = "".join(to_parse.split('Position:')[1])
            position = position.strip().split("\n")[0]
            #temp_player_df.loc[player_index,''] = shoots
        if "Draft" in to_parse:
            draft_data = to_parse.split("Draft:")[1].split(',')
            team = draft_data[0].strip()
            temp_player_df.loc[player_index,'draft_team'] = team

            if len(draft_data) == 4:
                pick_order = str(draft_data[1].strip())+","+str(draft_data[2].strip())
                draft_year_type = draft_data[3].strip()
                temp_player_df.loc[player_index,'pick_order'] = pick_order
                temp_player_df.loc[player_index,'draft_year_type'] = draft_year_type
            elif len(draft_data) == 3:
                pick_order = draft_data[1].strip()
                draft_year_type = draft_data[2].strip()
                temp_player_df.loc[player_index,'pick_order'] = pick_order
                temp_player_df.loc[player_index,'draft_year_type'] = draft_year_type
                
    return temp_player_df

# %%
player_df = get_player_df()
# Out:
# https://www.basketball-reference.com/players/a/abdelal01.html
# https://www.basketball-reference.com/players/a/abdulza01.html
# https://www.basketball-reference.com/players/a/abdulka01.html
# https://www.basketball-reference.com/players/a/abdulma02.html
# https://www.basketball-reference.com/players/a/abdulta01.html
# https://www.basketball-reference.com/players/a/abdursh01.html
# https://www.basketball-reference.com/players/a/abernto01.html
# https://www.basketball-reference.com/players/a/ablefo01.html
# https://www.basketball-reference.com/players/a/abramjo01.html
# https://www.basketball-reference.com/players/a/abrinal01.html
# https://www.basketball-reference.com/players/a/ackeral01.html
# https://www.basketball-reference.com/players/a/ackerdo01.html
# https://www.basketball-reference.com/players/a/acresma01.html
# https://www.basketball-reference.com/players/a/actonbu01.html
# https://www.basketball-reference.com/players/a/acyqu01.html
# https://www.basketball-reference.com/players/a/adamsal01.html
# https://www.basketball-reference.com/players/a/adamsdo01.html
# https://www.basketball-reference.com/players/a/adamsge01.html
# https://www.basketball-reference.com/players/a/adamsha01.html
# https://www.basketball-reference.com/players/a/adamsjo01.html
# https://www.basketball-reference.com/players/a/adamsmi01.html
# https://www.basketball-reference.com/players/a/adamsst01.html
# https://www.basketball-reference.com/players/a/addisra01.html
# https://www.basketball-reference.com/players/a/adelmri01.html
# https://www.basketball-reference.com/players/a/adrieje01.html
# https://www.basketball-reference.com/players/a/afflaar01.html
# https://www.basketball-reference.com/players/a/agerma01.html
# https://www.basketball-reference.com/players/a/aguirma01.html
# https://www.basketball-reference.com/players/a/ahearbl01.html
# https://www.basketball-reference.com/players/a/aingeda01.html
# https://www.basketball-reference.com/players/a/aitchma01.html
# https://www.basketball-reference.com/players/a/ajincal01.html
# https://www.basketball-reference.com/players/a/akinhe01.html
# https://www.basketball-reference.com/players/a/akognjo01.html
# https://www.basketball-reference.com/players/a/alabiso01.html
# https://www.basketball-reference.com/players/a/alarima01.html
# https://www.basketball-reference.com/players/a/alcorga01.html
# https://www.basketball-reference.com/players/a/aldemfu01.html
# https://www.basketball-reference.com/players/a/aldrico01.html
# https://www.basketball-reference.com/players/a/aldrila01.html
# https://www.basketball-reference.com/players/a/aleksch01.html
# https://www.basketball-reference.com/players/a/alexacl01.html
# https://www.basketball-reference.com/players/a/alexaco01.html
# https://www.basketball-reference.com/players/a/alexaco02.html
# https://www.basketball-reference.com/players/a/alexaga01.html
# https://www.basketball-reference.com/players/a/alexajo01.html
# https://www.basketball-reference.com/players/a/alexavi01.html
# https://www.basketball-reference.com/players/a/alforst01.html
# https://www.basketball-reference.com/players/a/allenbi01.html
# https://www.basketball-reference.com/players/a/allenbo01.html
# https://www.basketball-reference.com/players/a/allenje01.html
# https://www.basketball-reference.com/players/a/allenla01.html
# https://www.basketball-reference.com/players/a/allenlu01.html
# https://www.basketball-reference.com/players/a/allenma01.html
# https://www.basketball-reference.com/players/a/allenra01.html
# https://www.basketball-reference.com/players/a/allenra02.html
# https://www.basketball-reference.com/players/a/allento01.html
# https://www.basketball-reference.com/players/a/allenwi01.html
# https://www.basketball-reference.com/players/a/allisod01.html
# https://www.basketball-reference.com/players/a/allrela01.html
# https://www.basketball-reference.com/players/a/allumda01.html
# https://www.basketball-reference.com/players/a/almonmo01.html
# https://www.basketball-reference.com/players/a/alstode01.html
# https://www.basketball-reference.com/players/a/alstora01.html
# https://www.basketball-reference.com/players/a/alumape01.html
# https://www.basketball-reference.com/players/a/amaecjo01.html
# https://www.basketball-reference.com/players/a/amayaas01.html
# https://www.basketball-reference.com/players/a/aminual01.html
# https://www.basketball-reference.com/players/a/amundlo01.html
# https://www.basketball-reference.com/players/a/anderbo01.html
# https://www.basketball-reference.com/players/a/anderch01.html
# https://www.basketball-reference.com/players/a/anderda03.html
# https://www.basketball-reference.com/players/a/anderal01.html
# https://www.basketball-reference.com/players/a/anderan01.html
# https://www.basketball-reference.com/players/a/anderan02.html
# https://www.basketball-reference.com/players/a/andercl01.html
# https://www.basketball-reference.com/players/a/anderda01.html
# https://www.basketball-reference.com/players/a/anderda02.html
# https://www.basketball-reference.com/players/a/anderde01.html
# https://www.basketball-reference.com/players/a/anderdw01.html
# https://www.basketball-reference.com/players/a/anderer01.html
# https://www.basketball-reference.com/players/a/andergr01.html
# https://www.basketball-reference.com/players/a/anderjj01.html
# https://www.basketball-reference.com/players/a/anderja01.html
# https://www.basketball-reference.com/players/a/anderje01.html
# https://www.basketball-reference.com/players/a/anderju01.html
# https://www.basketball-reference.com/players/a/anderke01.html
# https://www.basketball-reference.com/players/a/anderki01.html
# https://www.basketball-reference.com/players/a/anderky01.html
# https://www.basketball-reference.com/players/a/andermi01.html
# https://www.basketball-reference.com/players/a/anderni01.html
# https://www.basketball-reference.com/players/a/anderri01.html
# https://www.basketball-reference.com/players/a/anderro01.html
# https://www.basketball-reference.com/players/a/anderry01.html
# https://www.basketball-reference.com/players/a/andersh01.html
# https://www.basketball-reference.com/players/a/anderwi01.html
# https://www.basketball-reference.com/players/a/anderwa01.html
# https://www.basketball-reference.com/players/a/andrima01.html
# https://www.basketball-reference.com/players/a/anieldo01.html
# https://www.basketball-reference.com/players/a/anslemi01.html
# https://www.basketball-reference.com/players/a/anstech01.html
# https://www.basketball-reference.com/players/a/antetgi01.html
# https://www.basketball-reference.com/players/a/antetth01.html
# https://www.basketball-reference.com/players/a/anthoca01.html
# https://www.basketball-reference.com/players/a/anthogr01.html
# https://www.basketball-reference.com/players/a/anthojo01.html
# https://www.basketball-reference.com/players/a/anticpe01.html
# https://www.basketball-reference.com/players/a/applike01.html
# https://www.basketball-reference.com/players/a/araujra01.html
# https://www.basketball-reference.com/players/a/arcenst01.html
# https://www.basketball-reference.com/players/a/archiro01.html
# https://www.basketball-reference.com/players/a/architi01.html
# https://www.basketball-reference.com/players/a/ardji01.html
# https://www.basketball-reference.com/players/a/arenagi01.html
# https://www.basketball-reference.com/players/a/arizatr01.html
# https://www.basketball-reference.com/players/a/arizipa01.html
# https://www.basketball-reference.com/players/a/arlaujo01.html
# https://www.basketball-reference.com/players/a/armstbj01.html
# https://www.basketball-reference.com/players/a/armstbo01.html
# https://www.basketball-reference.com/players/a/armstbr01.html
# https://www.basketball-reference.com/players/a/armstcu01.html
# https://www.basketball-reference.com/players/a/armstda01.html
# https://www.basketball-reference.com/players/a/armsthi01.html
# https://www.basketball-reference.com/players/a/armstta01.html
# https://www.basketball-reference.com/players/a/arnelje01.html
# https://www.basketball-reference.com/players/a/arnetja01.html
# https://www.basketball-reference.com/players/a/arnzebo01.html
# https://www.basketball-reference.com/players/a/arroyca01.html
# https://www.basketball-reference.com/players/a/arthuda01.html
# https://www.basketball-reference.com/players/a/arthujo01.html
# https://www.basketball-reference.com/players/a/asikom01.html
# https://www.basketball-reference.com/players/a/askewvi01.html
# https://www.basketball-reference.com/players/a/askinke01.html
# https://www.basketball-reference.com/players/a/asmondo01.html
# https://www.basketball-reference.com/players/a/athadi01.html
# https://www.basketball-reference.com/players/a/atkinch01.html
# https://www.basketball-reference.com/players/a/attleal01.html
# https://www.basketball-reference.com/players/a/aubucch01.html
# https://www.basketball-reference.com/players/a/augmost01.html
# https://www.basketball-reference.com/players/a/augusdj01.html
# https://www.basketball-reference.com/players/a/augusja01.html
# https://www.basketball-reference.com/players/a/austiis01.html
# https://www.basketball-reference.com/players/a/austijo01.html
# https://www.basketball-reference.com/players/a/austike01.html
# https://www.basketball-reference.com/players/a/aventan01.html
# https://www.basketball-reference.com/players/a/averibi01.html
# https://www.basketball-reference.com/players/a/averywi01.html
# https://www.basketball-reference.com/players/a/awtrede01.html
# https://www.basketball-reference.com/players/a/ayongu01.html
# https://www.basketball-reference.com/players/p/pendeje02.html
# https://www.basketball-reference.com/players/a/azubuke01.html
# https://www.basketball-reference.com/players/b/babbch01.html
# https://www.basketball-reference.com/players/b/babbilu01.html
# https://www.basketball-reference.com/players/b/babicmi01.html
# https://www.basketball-reference.com/players/b/bachjo01.html
# https://www.basketball-reference.com/players/b/baconhe01.html
# https://www.basketball-reference.com/players/b/baechji01.html
# https://www.basketball-reference.com/players/b/bagarda01.html
# https://www.basketball-reference.com/players/b/baglejo01.html
# https://www.basketball-reference.com/players/b/baileca01.html
# https://www.basketball-reference.com/players/b/bailegu01.html
# https://www.basketball-reference.com/players/b/baileja01.html
# https://www.basketball-reference.com/players/b/baileth01.html
# https://www.basketball-reference.com/players/b/baileto01.html
# https://www.basketball-reference.com/players/b/bairsca01.html
# https://www.basketball-reference.com/players/b/bakerji01.html
# https://www.basketball-reference.com/players/b/bakerla01.html
# https://www.basketball-reference.com/players/b/bakerma01.html
# https://www.basketball-reference.com/players/b/bakerno01.html
# https://www.basketball-reference.com/players/b/bakerro01.html
# https://www.basketball-reference.com/players/b/bakervi01.html
# https://www.basketball-reference.com/players/b/baldwwa01.html
# https://www.basketball-reference.com/players/b/balkmre01.html
# https://www.basketball-reference.com/players/b/ballce01.html
# https://www.basketball-reference.com/players/b/ballagr01.html
# https://www.basketball-reference.com/players/b/baltihe01.html
# https://www.basketball-reference.com/players/b/banksge01.html
# https://www.basketball-reference.com/players/b/banksma01.html
# https://www.basketball-reference.com/players/b/bankswa01.html
# https://www.basketball-reference.com/players/b/bannike01.html
# https://www.basketball-reference.com/players/b/bantomi01.html
# https://www.basketball-reference.com/players/b/barbejo01.html
# https://www.basketball-reference.com/players/b/barbole01.html
# https://www.basketball-reference.com/players/b/bardost01.html
# https://www.basketball-reference.com/players/b/bareajo01.html
# https://www.basketball-reference.com/players/b/bargnan01.html
# https://www.basketball-reference.com/players/b/barkecl01.html
# https://www.basketball-reference.com/players/b/barketo01.html
# https://www.basketball-reference.com/players/b/barklch01.html
# https://www.basketball-reference.com/players/b/barkler01.html
# https://www.basketball-reference.com/players/b/barksdo01.html
# https://www.basketball-reference.com/players/b/barneha02.html
# https://www.basketball-reference.com/players/b/barneha01.html
# https://www.basketball-reference.com/players/b/barneji01.html
# https://www.basketball-reference.com/players/b/barnema01.html
# https://www.basketball-reference.com/players/b/barnema02.html
# https://www.basketball-reference.com/players/b/barnedi01.html
# https://www.basketball-reference.com/players/b/barneji02.html
# https://www.basketball-reference.com/players/b/barnena01.html
# https://www.basketball-reference.com/players/b/barnhjo01.html
# https://www.basketball-reference.com/players/b/barnhno01.html
# https://www.basketball-reference.com/players/b/barnhle01.html
# https://www.basketball-reference.com/players/b/barrjo01.html
# https://www.basketball-reference.com/players/b/barrmi01.html
# https://www.basketball-reference.com/players/b/barrmo01.html
# https://www.basketball-reference.com/players/b/barrean01.html
# https://www.basketball-reference.com/players/b/barreer01.html
# https://www.basketball-reference.com/players/b/barremi01.html
# https://www.basketball-reference.com/players/b/barroea01.html
# https://www.basketball-reference.com/players/b/barroda01.html
# https://www.basketball-reference.com/players/b/barrybr01.html
# https://www.basketball-reference.com/players/b/barrydr01.html
# https://www.basketball-reference.com/players/b/barryjo01.html
# https://www.basketball-reference.com/players/b/barryri01.html
# https://www.basketball-reference.com/players/b/barteed01.html
# https://www.basketball-reference.com/players/b/bartovi01.html
# https://www.basketball-reference.com/players/b/bartowi01.html
# https://www.basketball-reference.com/players/b/basdeed01.html
# https://www.basketball-reference.com/players/b/baskeje01.html
# https://www.basketball-reference.com/players/b/bassbr01.html
# https://www.basketball-reference.com/players/b/basseti01.html
# https://www.basketball-reference.com/players/b/bastoma01.html
# https://www.basketball-reference.com/players/b/bateeme01.html
# https://www.basketball-reference.com/players/b/batesbi01.html
# https://www.basketball-reference.com/players/b/batises01.html
# https://www.basketball-reference.com/players/b/batismi01.html
# https://www.basketball-reference.com/players/b/battito01.html
# https://www.basketball-reference.com/players/b/battish01.html
# https://www.basketball-reference.com/players/b/battljo01.html
# https://www.basketball-reference.com/players/b/battlke01.html
# https://www.basketball-reference.com/players/b/battoda01.html
# https://www.basketball-reference.com/players/b/battsll01.html
# https://www.basketball-reference.com/players/b/batumni01.html
# https://www.basketball-reference.com/players/b/baumjo01.html
# https://www.basketball-reference.com/players/b/baumhfr01.html
# https://www.basketball-reference.com/players/b/baxtelo01.html
# https://www.basketball-reference.com/players/b/bayleje01.html
# https://www.basketball-reference.com/players/b/bayloel01.html
# https://www.basketball-reference.com/players/b/bayneho01.html
# https://www.basketball-reference.com/players/b/baynear01.html
# https://www.basketball-reference.com/players/b/bazarse01.html
# https://www.basketball-reference.com/players/b/bazemke01.html
# https://www.basketball-reference.com/players/b/beached01.html
# https://www.basketball-reference.com/players/b/bealbr01.html
# https://www.basketball-reference.com/players/b/beardal01.html
# https://www.basketball-reference.com/players/b/beardbu01.html
# https://www.basketball-reference.com/players/b/beardra01.html
# https://www.basketball-reference.com/players/b/beaslch01.html
# https://www.basketball-reference.com/players/b/beaslje01.html
# https://www.basketball-reference.com/players/b/beasljo01.html
# https://www.basketball-reference.com/players/b/beaslma01.html
# https://www.basketball-reference.com/players/b/beaslmi01.html
# https://www.basketball-reference.com/players/b/beatyze01.html
# https://www.basketball-reference.com/players/b/beaubro01.html
# https://www.basketball-reference.com/players/b/beckby01.html
# https://www.basketball-reference.com/players/b/beckco01.html
# https://www.basketball-reference.com/players/b/becker01.html
# https://www.basketball-reference.com/players/b/beckear01.html
# https://www.basketball-reference.com/players/b/beckemo01.html
# https://www.basketball-reference.com/players/b/bedelbo01.html
# https://www.basketball-reference.com/players/b/bedfowi01.html
# https://www.basketball-reference.com/players/b/beendha01.html
# https://www.basketball-reference.com/players/b/behagro01.html
# https://www.basketball-reference.com/players/b/behnkel01.html
# https://www.basketball-reference.com/players/b/belinma01.html
# https://www.basketball-reference.com/players/b/bellch01.html
# https://www.basketball-reference.com/players/b/bellde01.html
# https://www.basketball-reference.com/players/b/bellra01.html
# https://www.basketball-reference.com/players/b/belltr01.html
# https://www.basketball-reference.com/players/b/bellwh01.html
# https://www.basketball-reference.com/players/b/bellawa01.html
# https://www.basketball-reference.com/players/b/bembrde01.html
# https://www.basketball-reference.com/players/b/bemorir01.html
# https://www.basketball-reference.com/players/b/benbole01.html
# https://www.basketball-reference.com/players/b/bendedr01.html
# https://www.basketball-reference.com/players/b/bendejo01.html
# https://www.basketball-reference.com/players/b/benimje01.html
# https://www.basketball-reference.com/players/b/benjabe01.html
# https://www.basketball-reference.com/players/b/benjaco01.html
# https://www.basketball-reference.com/players/b/bennean01.html
# https://www.basketball-reference.com/players/b/benneel01.html
# https://www.basketball-reference.com/players/b/bennema01.html
# https://www.basketball-reference.com/players/b/benneme01.html
# https://www.basketball-reference.com/players/b/bennesp01.html
# https://www.basketball-reference.com/players/b/benneto01.html
# https://www.basketball-reference.com/players/b/bennewi01.html
# https://www.basketball-reference.com/players/b/benoida01.html
# https://www.basketball-reference.com/players/b/bensoke02.html
# https://www.basketball-reference.com/players/b/bensoke01.html
# https://www.basketball-reference.com/players/b/bentibe01.html
# https://www.basketball-reference.com/players/b/bercege01.html
# https://www.basketball-reference.com/players/b/bergega01.html
# https://www.basketball-reference.com/players/b/berghla01.html
# https://www.basketball-reference.com/players/b/berryri01.html
# https://www.basketball-reference.com/players/b/berrywa01.html
# https://www.basketball-reference.com/players/b/bertada01.html
# https://www.basketball-reference.com/players/b/beshode01.html
# https://www.basketball-reference.com/players/b/besttr01.html
# https://www.basketball-reference.com/players/b/beverpa01.html
# https://www.basketball-reference.com/players/b/bhullsi01.html
# https://www.basketball-reference.com/players/b/bialowe01.html
# https://www.basketball-reference.com/players/b/biancal01.html
# https://www.basketball-reference.com/players/b/biasaha01.html
# https://www.basketball-reference.com/players/b/bibbyhe01.html
# https://www.basketball-reference.com/players/b/bibbymi01.html
# https://www.basketball-reference.com/players/b/biedeed01.html
# https://www.basketball-reference.com/players/b/biedran01.html
# https://www.basketball-reference.com/players/b/bielkdo01.html
# https://www.basketball-reference.com/players/b/bigelbo01.html
# https://www.basketball-reference.com/players/b/billili01.html
# https://www.basketball-reference.com/players/b/billuch01.html
# https://www.basketball-reference.com/players/b/bingda01.html
# https://www.basketball-reference.com/players/b/biniojo01.html
# https://www.basketball-reference.com/players/b/birdje01.html
# https://www.basketball-reference.com/players/b/birdla01.html
# https://www.basketball-reference.com/players/b/birdsot01.html
# https://www.basketball-reference.com/players/b/bishoga01.html
# https://www.basketball-reference.com/players/b/biyombi01.html
# https://www.basketball-reference.com/players/b/bjeline01.html
# https://www.basketball-reference.com/players/b/blabuw01.html
# https://www.basketball-reference.com/players/b/blackch01.html
# https://www.basketball-reference.com/players/b/blackno01.html
# https://www.basketball-reference.com/players/b/blackta01.html
# https://www.basketball-reference.com/players/b/blackto01.html
# https://www.basketball-reference.com/players/b/blackro01.html
# https://www.basketball-reference.com/players/b/blackal01.html
# https://www.basketball-reference.com/players/b/blackco01.html
# https://www.basketball-reference.com/players/b/blackja01.html
# https://www.basketball-reference.com/players/b/blackna01.html
# https://www.basketball-reference.com/players/b/blairde01.html
# https://www.basketball-reference.com/players/b/blakest01.html
# https://www.basketball-reference.com/players/b/blalowi01.html
# https://www.basketball-reference.com/players/b/blanege01.html
# https://www.basketball-reference.com/players/b/blankla01.html
# https://www.basketball-reference.com/players/b/blantri01.html
# https://www.basketball-reference.com/players/b/blatcan01.html
# https://www.basketball-reference.com/players/b/blaylmo01.html
# https://www.basketball-reference.com/players/b/bledser01.html
# https://www.basketball-reference.com/players/b/blevile01.html
# https://www.basketball-reference.com/players/b/blockjo01.html
# https://www.basketball-reference.com/players/b/bloommi01.html
# https://www.basketball-reference.com/players/b/blounco01.html
# https://www.basketball-reference.com/players/b/blounma01.html
# https://www.basketball-reference.com/players/b/blueva01.html
# https://www.basketball-reference.com/players/b/blumera01.html
# https://www.basketball-reference.com/players/b/bobbne01.html
# https://www.basketball-reference.com/players/b/bobbito01.html
# https://www.basketball-reference.com/players/b/bockhbu01.html
# https://www.basketball-reference.com/players/b/boerwto01.html
# https://www.basketball-reference.com/players/b/boganke01.html
# https://www.basketball-reference.com/players/b/bogdabo02.html
# https://www.basketball-reference.com/players/b/boguemu01.html
# https://www.basketball-reference.com/players/b/bogutan01.html
# https://www.basketball-reference.com/players/b/bohanet01.html
# https://www.basketball-reference.com/players/b/bolma01.html
# https://www.basketball-reference.com/players/b/bolgebi01.html
# https://www.basketball-reference.com/players/b/bolomjo01.html
# https://www.basketball-reference.com/players/b/bolstdo01.html
# https://www.basketball-reference.com/players/b/bonsage01.html
# https://www.basketball-reference.com/players/b/bondph01.html
# https://www.basketball-reference.com/players/b/bondwa01.html
# https://www.basketball-reference.com/players/b/boneyde01.html
# https://www.basketball-reference.com/players/b/bonharo01.html
# https://www.basketball-reference.com/players/b/bonnean01.html
# https://www.basketball-reference.com/players/b/bonnema01.html
# https://www.basketball-reference.com/players/b/bookebu01.html
# https://www.basketball-reference.com/players/b/bookede01.html
# https://www.basketball-reference.com/players/b/bookeme01.html
# https://www.basketball-reference.com/players/b/booketr01.html
# https://www.basketball-reference.com/players/b/boonejo01.html
# https://www.basketball-reference.com/players/b/boonero01.html
# https://www.basketball-reference.com/players/b/boothca01.html
# https://www.basketball-reference.com/players/b/boothke01.html
# https://www.basketball-reference.com/players/b/boozebo01.html
# https://www.basketball-reference.com/players/b/boozeca01.html
# https://www.basketball-reference.com/players/b/borchcu01.html
# https://www.basketball-reference.com/players/b/bornhja01.html
# https://www.basketball-reference.com/players/b/borrela01.html
# https://www.basketball-reference.com/players/b/borsaik01.html
# https://www.basketball-reference.com/players/b/borylvi01.html
# https://www.basketball-reference.com/players/b/boshch01.html
# https://www.basketball-reference.com/players/b/bostiji01.html
# https://www.basketball-reference.com/players/b/bostola01.html
# https://www.basketball-reference.com/players/b/bosweto01.html
# https://www.basketball-reference.com/players/b/boumtru01.html
# https://www.basketball-reference.com/players/b/bovendo01.html
# https://www.basketball-reference.com/players/b/bowdlca01.html
# https://www.basketball-reference.com/players/b/bowenbr01.html
# https://www.basketball-reference.com/players/b/bowenry01.html
# https://www.basketball-reference.com/players/b/bowento01.html
# https://www.basketball-reference.com/players/b/bowiean01.html
# https://www.basketball-reference.com/players/b/bowiesa01.html
# https://www.basketball-reference.com/players/b/bowlior01.html
# https://www.basketball-reference.com/players/b/bowmair01.html
# https://www.basketball-reference.com/players/b/bowmana01.html
# https://www.basketball-reference.com/players/b/boycedo01.html
# https://www.basketball-reference.com/players/b/boydde01.html
# https://www.basketball-reference.com/players/b/boydfr01.html
# https://www.basketball-reference.com/players/b/boydke01.html
# https://www.basketball-reference.com/players/b/boykiea01.html
# https://www.basketball-reference.com/players/b/boykoha01.html
# https://www.basketball-reference.com/players/b/boynewi01.html
# https://www.basketball-reference.com/players/b/bozemce01.html
# https://www.basketball-reference.com/players/b/bracest01.html
# https://www.basketball-reference.com/players/b/brackcr01.html
# https://www.basketball-reference.com/players/b/braddga01.html
# https://www.basketball-reference.com/players/b/bradlal02.html
# https://www.basketball-reference.com/players/b/bradlal01.html
# https://www.basketball-reference.com/players/b/bradlav01.html
# https://www.basketball-reference.com/players/b/bradlbi02.html
# https://www.basketball-reference.com/players/b/bradlbi01.html
# https://www.basketball-reference.com/players/b/bradlch01.html
# https://www.basketball-reference.com/players/b/bradldu01.html
# https://www.basketball-reference.com/players/b/bradlji01.html
# https://www.basketball-reference.com/players/b/bradljo01.html
# https://www.basketball-reference.com/players/b/bradlmi01.html
# https://www.basketball-reference.com/players/b/bradlsh01.html
# https://www.basketball-reference.com/players/b/bradtma01.html
# https://www.basketball-reference.com/players/b/braggma01.html
# https://www.basketball-reference.com/players/b/braggto01.html
# https://www.basketball-reference.com/players/b/bramlaj01.html
# https://www.basketball-reference.com/players/b/brancad01.html
# https://www.basketball-reference.com/players/b/brandel01.html
# https://www.basketball-reference.com/players/b/brandte01.html
# https://www.basketball-reference.com/players/b/brannbo01.html
# https://www.basketball-reference.com/players/b/bransbr01.html
# https://www.basketball-reference.com/players/b/bransje01.html
# https://www.basketball-reference.com/players/b/brascji01.html
# https://www.basketball-reference.com/players/b/bratzmi01.html
# https://www.basketball-reference.com/players/b/braunca01.html
# https://www.basketball-reference.com/players/b/breauti01.html
# https://www.basketball-reference.com/players/b/bremejr01.html
# https://www.basketball-reference.com/players/b/brennpe01.html
# https://www.basketball-reference.com/players/b/brennto01.html
# https://www.basketball-reference.com/players/b/breuera01.html
# https://www.basketball-reference.com/players/b/breweco01.html
# https://www.basketball-reference.com/players/b/breweja01.html
# https://www.basketball-reference.com/players/b/breweji01.html
# https://www.basketball-reference.com/players/b/brewero01.html
# https://www.basketball-reference.com/players/b/brewero02.html
# https://www.basketball-reference.com/players/b/brezepr01.html
# https://www.basketball-reference.com/players/b/brianfr01.html
# https://www.basketball-reference.com/players/b/brickfr01.html
# https://www.basketball-reference.com/players/b/bridgju01.html
# https://www.basketball-reference.com/players/b/bridgbi01.html
# https://www.basketball-reference.com/players/b/brighal01.html
# https://www.basketball-reference.com/players/b/brindau01.html
# https://www.basketball-reference.com/players/b/briskjo01.html
# https://www.basketball-reference.com/players/b/bristal01.html
# https://www.basketball-reference.com/players/b/brittty01.html
# https://www.basketball-reference.com/players/b/brittwa01.html
# https://www.basketball-reference.com/players/b/brittmi01.html
# https://www.basketball-reference.com/players/b/brittda01.html
# https://www.basketball-reference.com/players/b/brockjo01.html
# https://www.basketball-reference.com/players/b/brogaji01.html
# https://www.basketball-reference.com/players/b/brogdma01.html
# https://www.basketball-reference.com/players/b/brokaga01.html
# https://www.basketball-reference.com/players/b/brookpr01.html
# https://www.basketball-reference.com/players/b/brookcl01.html
# https://www.basketball-reference.com/players/b/brookaa01.html
# https://www.basketball-reference.com/players/b/brookke01.html
# https://www.basketball-reference.com/players/b/brookma01.html
# https://www.basketball-reference.com/players/b/brookmi01.html
# https://www.basketball-reference.com/players/b/brooksc01.html
# https://www.basketball-reference.com/players/b/brownan01.html
# https://www.basketball-reference.com/players/b/brownan02.html
# https://www.basketball-reference.com/players/b/brownbo01.html
# https://www.basketball-reference.com/players/b/brownbo02.html
# https://www.basketball-reference.com/players/b/brownch01.html
# https://www.basketball-reference.com/players/b/brownda02.html
# https://www.basketball-reference.com/players/b/brownda01.html
# https://www.basketball-reference.com/players/b/brownde01.html
# https://www.basketball-reference.com/players/b/brownde03.html
# https://www.basketball-reference.com/players/b/brownde04.html
# https://www.basketball-reference.com/players/b/brownde02.html
# https://www.basketball-reference.com/players/b/browner01.html
# https://www.basketball-reference.com/players/b/brownfr01.html
# https://www.basketball-reference.com/players/b/brownge01.html
# https://www.basketball-reference.com/players/b/brownge02.html
# https://www.basketball-reference.com/players/b/brownha01.html
# https://www.basketball-reference.com/players/b/brownja01.html
# https://www.basketball-reference.com/players/b/brownja02.html
# https://www.basketball-reference.com/players/b/brownjo01.html
# https://www.basketball-reference.com/players/b/brownke01.html
# https://www.basketball-reference.com/players/b/brownkw01.html
# https://www.basketball-reference.com/players/b/brownla01.html
# https://www.basketball-reference.com/players/b/brownle01.html
# https://www.basketball-reference.com/players/b/brownle02.html
# https://www.basketball-reference.com/players/b/brownlo01.html
# https://www.basketball-reference.com/players/b/brownma01.html
# https://www.basketball-reference.com/players/b/brownma02.html
# https://www.basketball-reference.com/players/b/brownmi01.html
# https://www.basketball-reference.com/players/b/brownmy01.html
# https://www.basketball-reference.com/players/b/brownpj01.html
# https://www.basketball-reference.com/players/b/brownra02.html
# https://www.basketball-reference.com/players/b/brownra01.html
# https://www.basketball-reference.com/players/b/brownri01.html
# https://www.basketball-reference.com/players/b/brownro01.html
# https://www.basketball-reference.com/players/b/brownro02.html
# https://www.basketball-reference.com/players/b/brownsh01.html
# https://www.basketball-reference.com/players/b/brownst01.html
# https://www.basketball-reference.com/players/b/brownti01.html
# https://www.basketball-reference.com/players/b/brownto01.html
# https://www.basketball-reference.com/players/b/brownji01.html
# https://www.basketball-reference.com/players/b/brundst01.html
# https://www.basketball-reference.com/players/b/brunkbr01.html
# https://www.basketball-reference.com/players/b/brunsge01.html
# https://www.basketball-reference.com/players/b/brunsri01.html
# https://www.basketball-reference.com/players/b/brussni01.html
# https://www.basketball-reference.com/players/b/bryanem01.html
# https://www.basketball-reference.com/players/b/bryanjo01.html
# https://www.basketball-reference.com/players/b/bryanko01.html
# https://www.basketball-reference.com/players/b/bryanma01.html
# https://www.basketball-reference.com/players/b/bryanwa01.html
# https://www.basketball-reference.com/players/b/brynto01.html
# https://www.basketball-reference.com/players/b/buccige01.html
# https://www.basketball-reference.com/players/b/buckhjo01.html
# https://www.basketball-reference.com/players/b/bucknst01.html
# https://www.basketball-reference.com/players/b/buckncl01.html
# https://www.basketball-reference.com/players/b/buckngr01.html
# https://www.basketball-reference.com/players/b/bucknqu01.html
# https://www.basketball-reference.com/players/b/buddda01.html
# https://www.basketball-reference.com/players/b/budinch01.html
# https://www.basketball-reference.com/players/b/budkowa01.html
# https://www.basketball-reference.com/players/b/buechju01.html
# https://www.basketball-reference.com/players/b/buforro01.html
# https://www.basketball-reference.com/players/b/bullama01.html
# https://www.basketball-reference.com/players/b/bullore01.html
# https://www.basketball-reference.com/players/b/buncela01.html
# https://www.basketball-reference.com/players/b/bunchgr01.html
# https://www.basketball-reference.com/players/b/buntdi01.html
# https://www.basketball-reference.com/players/b/buntibi01.html
# https://www.basketball-reference.com/players/b/buntibi02.html
# https://www.basketball-reference.com/players/b/burdeti01.html
# https://www.basketball-reference.com/players/b/burkepa01.html
# https://www.basketball-reference.com/players/b/burketr01.html
# https://www.basketball-reference.com/players/b/burkmro01.html
# https://www.basketball-reference.com/players/b/burksal01.html
# https://www.basketball-reference.com/players/b/burksan01.html
# https://www.basketball-reference.com/players/b/burleke01.html
# https://www.basketball-reference.com/players/b/burleto01.html
# https://www.basketball-reference.com/players/b/burmaja01.html
# https://www.basketball-reference.com/players/b/burnsda01.html
# https://www.basketball-reference.com/players/b/burnsev01.html
# https://www.basketball-reference.com/players/b/burnsji01.html
# https://www.basketball-reference.com/players/b/burresc01.html
# https://www.basketball-reference.com/players/b/burriar01.html
# https://www.basketball-reference.com/players/b/burroju01.html
# https://www.basketball-reference.com/players/b/burrobo01.html
# https://www.basketball-reference.com/players/b/burtoed01.html
# https://www.basketball-reference.com/players/b/burtowi01.html
# https://www.basketball-reference.com/players/b/burttst01.html
# https://www.basketball-reference.com/players/b/busedo01.html
# https://www.basketball-reference.com/players/b/bustida01.html
# https://www.basketball-reference.com/players/b/butchdo01.html
# https://www.basketball-reference.com/players/b/butleal01.html
# https://www.basketball-reference.com/players/b/butleca01.html
# https://www.basketball-reference.com/players/b/butlegr01.html
# https://www.basketball-reference.com/players/b/butleja01.html
# https://www.basketball-reference.com/players/b/butleji01.html
# https://www.basketball-reference.com/players/b/butlemi01.html
# https://www.basketball-reference.com/players/b/butlemi02.html
# https://www.basketball-reference.com/players/b/butlera01.html
# https://www.basketball-reference.com/players/b/buyckdw01.html
# https://www.basketball-reference.com/players/b/byarsde01.html
# https://www.basketball-reference.com/players/b/bynuman01.html
# https://www.basketball-reference.com/players/b/bynumwi01.html
# https://www.basketball-reference.com/players/b/byrdwa01.html
# https://www.basketball-reference.com/players/b/byrnema01.html
# https://www.basketball-reference.com/players/b/byrneto01.html
# https://www.basketball-reference.com/players/b/bytzumi01.html
# https://www.basketball-reference.com/players/c/cabarza01.html
# https://www.basketball-reference.com/players/c/cableba01.html
# https://www.basketball-reference.com/players/c/cabocbr01.html
# https://www.basketball-reference.com/players/c/caffeja01.html
# https://www.basketball-reference.com/players/c/cagemi01.html
# https://www.basketball-reference.com/players/c/calabge01.html
# https://www.basketball-reference.com/players/c/calatni01.html
# https://www.basketball-reference.com/players/c/caldejo01.html
# https://www.basketball-reference.com/players/c/caldwad01.html
# https://www.basketball-reference.com/players/c/caldwji01.html
# https://www.basketball-reference.com/players/c/caldwjo01.html
# https://www.basketball-reference.com/players/c/caldwke01.html
# https://www.basketball-reference.com/players/c/calhobi01.html
# https://www.basketball-reference.com/players/c/calhoco01.html
# https://www.basketball-reference.com/players/c/calipde01.html
# https://www.basketball-reference.com/players/c/callato01.html
# https://www.basketball-reference.com/players/c/callori01.html
# https://www.basketball-reference.com/players/c/calveer01.html
# https://www.basketball-reference.com/players/c/calvima01.html
# https://www.basketball-reference.com/players/c/cambrde01.html
# https://www.basketball-reference.com/players/c/cambyma01.html
# https://www.basketball-reference.com/players/c/campbel01.html
# https://www.basketball-reference.com/players/c/campbto01.html
# https://www.basketball-reference.com/players/c/canaais01.html
# https://www.basketball-reference.com/players/c/cannola01.html
# https://www.basketball-reference.com/players/c/capelca01.html
# https://www.basketball-reference.com/players/c/caracde01.html
# https://www.basketball-reference.com/players/c/cardfr01.html
# https://www.basketball-reference.com/players/c/cardibr01.html
# https://www.basketball-reference.com/players/c/carlho01.html
# https://www.basketball-reference.com/players/c/carlich01.html
# https://www.basketball-reference.com/players/c/carlige01.html
# https://www.basketball-reference.com/players/c/carliri01.html
# https://www.basketball-reference.com/players/c/carlodo01.html
# https://www.basketball-reference.com/players/c/carlsal01.html
# https://www.basketball-reference.com/players/c/carlsdo01.html
# https://www.basketball-reference.com/players/c/carnebo01.html
# https://www.basketball-reference.com/players/c/carnero01.html
# https://www.basketball-reference.com/players/c/carpebo01.html
# https://www.basketball-reference.com/players/c/carran01.html
# https://www.basketball-reference.com/players/c/carrau01.html
# https://www.basketball-reference.com/players/c/carrch01.html
# https://www.basketball-reference.com/players/c/carrco01.html
# https://www.basketball-reference.com/players/c/carrke01.html
# https://www.basketball-reference.com/players/c/carrml01.html
# https://www.basketball-reference.com/players/c/carrida01.html
# https://www.basketball-reference.com/players/c/carribo01.html
# https://www.basketball-reference.com/players/c/carrode01.html
# https://www.basketball-reference.com/players/c/carrojo01.html
# https://www.basketball-reference.com/players/c/carroma01.html
# https://www.basketball-reference.com/players/c/carruji01.html
# https://www.basketball-reference.com/players/c/cartean01.html
# https://www.basketball-reference.com/players/c/cartebu01.html
# https://www.basketball-reference.com/players/c/cartefr01.html
# https://www.basketball-reference.com/players/c/cartege01.html
# https://www.basketball-reference.com/players/c/carteho01.html
# https://www.basketball-reference.com/players/c/carteja01.html
# https://www.basketball-reference.com/players/c/cartema01.html
# https://www.basketball-reference.com/players/c/cartere01.html
# https://www.basketball-reference.com/players/c/cartero01.html
# https://www.basketball-reference.com/players/c/cartevi01.html
# https://www.basketball-reference.com/players/c/cartemi01.html
# https://www.basketball-reference.com/players/c/cartwbi01.html
# https://www.basketball-reference.com/players/c/cartyja01.html
# https://www.basketball-reference.com/players/c/cashco01.html
# https://www.basketball-reference.com/players/c/cashsa01.html
# https://www.basketball-reference.com/players/c/cassesa01.html
# https://www.basketball-reference.com/players/c/casspom01.html
# https://www.basketball-reference.com/players/c/catchha01.html
# https://www.basketball-reference.com/players/c/catlete01.html
# https://www.basketball-reference.com/players/c/catlesi01.html
# https://www.basketball-reference.com/players/c/catoke01.html
# https://www.basketball-reference.com/players/c/cattabo01.html
# https://www.basketball-reference.com/players/c/caulewi01.html
# https://www.basketball-reference.com/players/c/causwdu01.html
# https://www.basketball-reference.com/players/c/cavenro01.html
# https://www.basketball-reference.com/players/c/cebalce01.html
# https://www.basketball-reference.com/players/c/celesjo01.html
# https://www.basketball-reference.com/players/c/cervial01.html
# https://www.basketball-reference.com/players/c/chalmli01.html
# https://www.basketball-reference.com/players/c/chalmma01.html
# https://www.basketball-reference.com/players/c/chambbi01.html
# https://www.basketball-reference.com/players/c/chambwi01.html
# https://www.basketball-reference.com/players/c/chambje01.html
# https://www.basketball-reference.com/players/c/chambto01.html
# https://www.basketball-reference.com/players/c/champmi01.html
# https://www.basketball-reference.com/players/c/chandty01.html
# https://www.basketball-reference.com/players/c/chandwi01.html
# https://www.basketball-reference.com/players/c/chanedo01.html
# https://www.basketball-reference.com/players/c/chanejo01.html
# https://www.basketball-reference.com/players/c/chapmre01.html
# https://www.basketball-reference.com/players/c/chapmwa01.html
# https://www.basketball-reference.com/players/c/chapple01.html
# https://www.basketball-reference.com/players/c/charlke01.html
# https://www.basketball-reference.com/players/c/charllo01.html
# https://www.basketball-reference.com/players/c/cheanca01.html
# https://www.basketball-reference.com/players/c/cheekma01.html
# https://www.basketball-reference.com/players/c/cheniph01.html
# https://www.basketball-reference.com/players/c/cherrwi01.html
# https://www.basketball-reference.com/players/c/chievde01.html
# https://www.basketball-reference.com/players/c/chilcpe01.html
# https://www.basketball-reference.com/players/c/childjo01.html
# https://www.basketball-reference.com/players/c/childra01.html
# https://www.basketball-reference.com/players/c/childch01.html
# https://www.basketball-reference.com/players/c/chollle01.html
# https://www.basketball-reference.com/players/c/choneji01.html
# https://www.basketball-reference.com/players/c/chrisma01.html
# https://www.basketball-reference.com/players/c/chrisfr01.html
# https://www.basketball-reference.com/players/c/chrisca01.html
# https://www.basketball-reference.com/players/c/chrisbo01.html
# https://www.basketball-reference.com/players/c/chrisdo01.html
# https://www.basketball-reference.com/players/c/chrisdi01.html
# https://www.basketball-reference.com/players/c/chrisra01.html
# https://www.basketball-reference.com/players/c/chrisse01.html
# https://www.basketball-reference.com/players/c/chrispa01.html
# https://www.basketball-reference.com/players/c/chubist01.html
# https://www.basketball-reference.com/players/c/churcro01.html
# https://www.basketball-reference.com/players/c/clarkar01.html
# https://www.basketball-reference.com/players/c/clarkca01.html
# https://www.basketball-reference.com/players/c/clarkea01.html
# https://www.basketball-reference.com/players/c/clarkia01.html
# https://www.basketball-reference.com/players/c/clarkke01.html
# https://www.basketball-reference.com/players/c/clarkri01.html
# https://www.basketball-reference.com/players/c/clarkco01.html
# https://www.basketball-reference.com/players/c/clarkjo01.html
# https://www.basketball-reference.com/players/c/clavevi01.html
# https://www.basketball-reference.com/players/c/clawsjo01.html
# https://www.basketball-reference.com/players/c/claxtch01.html
# https://www.basketball-reference.com/players/c/claxtsp01.html
# https://www.basketball-reference.com/players/c/cleamji01.html
# https://www.basketball-reference.com/players/c/cleavma01.html
# https://www.basketball-reference.com/players/c/clemeba01.html
# https://www.basketball-reference.com/players/c/cliftna01.html
# https://www.basketball-reference.com/players/c/clossbi01.html
# https://www.basketball-reference.com/players/c/closske01.html
# https://www.basketball-reference.com/players/c/cloydpa01.html
# https://www.basketball-reference.com/players/c/cluggbo01.html
# https://www.basketball-reference.com/players/c/clydebe01.html
# https://www.basketball-reference.com/players/c/cofferi01.html
# https://www.basketball-reference.com/players/c/cofiefr01.html
# https://www.basketball-reference.com/players/c/cokerjo01.html
# https://www.basketball-reference.com/players/c/coleno01.html
# https://www.basketball-reference.com/players/c/colembe01.html
# https://www.basketball-reference.com/players/c/colemde01.html
# https://www.basketball-reference.com/players/c/colemec01.html
# https://www.basketball-reference.com/players/c/colemja01.html
# https://www.basketball-reference.com/players/c/colemno01.html
# https://www.basketball-reference.com/players/c/colesbi01.html
# https://www.basketball-reference.com/players/c/collija02.html
# https://www.basketball-reference.com/players/c/colliar01.html
# https://www.basketball-reference.com/players/c/collido02.html
# https://www.basketball-reference.com/players/c/collido01.html
# https://www.basketball-reference.com/players/c/collija01.html
# https://www.basketball-reference.com/players/c/collija03.html
# https://www.basketball-reference.com/players/c/collija04.html
# https://www.basketball-reference.com/players/c/colliji01.html
# https://www.basketball-reference.com/players/c/collima01.html
# https://www.basketball-reference.com/players/c/collish01.html
# https://www.basketball-reference.com/players/c/collida01.html
# https://www.basketball-reference.com/players/c/collini01.html
# https://www.basketball-reference.com/players/c/colonjo01.html
# https://www.basketball-reference.com/players/c/colsose01.html
# https://www.basketball-reference.com/players/c/coltest01.html
# https://www.basketball-reference.com/players/c/combsgl01.html
# https://www.basketball-reference.com/players/c/combsle01.html
# https://www.basketball-reference.com/players/c/comeajo01.html
# https://www.basketball-reference.com/players/c/comegda01.html
# https://www.basketball-reference.com/players/c/comlela01.html
# https://www.basketball-reference.com/players/c/congdje01.html
# https://www.basketball-reference.com/players/c/conlege01.html
# https://www.basketball-reference.com/players/c/conlela01.html
# https://www.basketball-reference.com/players/c/conlemi01.html
# https://www.basketball-reference.com/players/c/conlied01.html
# https://www.basketball-reference.com/players/c/conloma01.html
# https://www.basketball-reference.com/players/c/connapa01.html
# https://www.basketball-reference.com/players/c/conneji01.html
# https://www.basketball-reference.com/players/c/connele01.html
# https://www.basketball-reference.com/players/c/connoch01.html
# https://www.basketball-reference.com/players/c/conrowi01.html
# https://www.basketball-reference.com/players/c/cookan01.html
# https://www.basketball-reference.com/players/c/cookbe01.html
# https://www.basketball-reference.com/players/c/cookbo01.html
# https://www.basketball-reference.com/players/c/cookbr01.html
# https://www.basketball-reference.com/players/c/cookda02.html
# https://www.basketball-reference.com/players/c/cookda01.html
# https://www.basketball-reference.com/players/c/cookje01.html
# https://www.basketball-reference.com/players/c/cookno01.html
# https://www.basketball-reference.com/players/c/cookom01.html
# https://www.basketball-reference.com/players/c/cookqu01.html
# https://www.basketball-reference.com/players/c/cookeda01.html
# https://www.basketball-reference.com/players/c/cookejo01.html
# https://www.basketball-reference.com/players/c/cooleja01.html
# https://www.basketball-reference.com/players/c/coopech01.html
# https://www.basketball-reference.com/players/c/coopedu01.html
# https://www.basketball-reference.com/players/c/coopejo01.html
# https://www.basketball-reference.com/players/c/coopemi01.html
# https://www.basketball-reference.com/players/c/coopewa01.html
# https://www.basketball-reference.com/players/c/copato01.html
# https://www.basketball-reference.com/players/c/copelch01.html
# https://www.basketball-reference.com/players/c/copelho01.html
# https://www.basketball-reference.com/players/c/copella01.html
# https://www.basketball-reference.com/players/c/corbity01.html
# https://www.basketball-reference.com/players/c/corchch01.html
# https://www.basketball-reference.com/players/c/corleke01.html
# ...
# https://www.basketball-reference.com/players/w/westdo01.html
# https://www.basketball-reference.com/players/w/westje01.html
# https://www.basketball-reference.com/players/w/westma02.html
# https://www.basketball-reference.com/players/w/westma01.html
# https://www.basketball-reference.com/players/w/westro01.html
# https://www.basketball-reference.com/players/w/westbde01.html
# https://www.basketball-reference.com/players/w/westbru01.html
# https://www.basketball-reference.com/players/w/westppa01.html
# https://www.basketball-reference.com/players/w/wetzejo01.html
# https://www.basketball-reference.com/players/w/whalero01.html
# https://www.basketball-reference.com/players/w/whatlen01.html
# https://www.basketball-reference.com/players/w/wheatde01.html
# https://www.basketball-reference.com/players/w/wheelcl01.html
# https://www.basketball-reference.com/players/w/wheelty01.html
# https://www.basketball-reference.com/players/w/whitask01.html
# https://www.basketball-reference.com/players/w/whitedj01.html
# https://www.basketball-reference.com/players/w/whiteer01.html
# https://www.basketball-reference.com/players/w/whitehe01.html
# https://www.basketball-reference.com/players/w/whitehu01.html
# https://www.basketball-reference.com/players/w/whiteja01.html
# https://www.basketball-reference.com/players/w/whiteja02.html
# https://www.basketball-reference.com/players/w/whitejo01.html
# https://www.basketball-reference.com/players/w/whiteok01.html
# https://www.basketball-reference.com/players/w/whitera01.html
# https://www.basketball-reference.com/players/w/whitero02.html
# https://www.basketball-reference.com/players/w/whitero01.html
# https://www.basketball-reference.com/players/w/whitero03.html
# https://www.basketball-reference.com/players/w/whiteru01.html
# https://www.basketball-reference.com/players/w/whiteto01.html
# https://www.basketball-reference.com/players/w/whitewi01.html
# https://www.basketball-reference.com/players/w/whiteis01.html
# https://www.basketball-reference.com/players/w/whiteje01.html
# https://www.basketball-reference.com/players/w/whitedo01.html
# https://www.basketball-reference.com/players/w/whiteha01.html
# https://www.basketball-reference.com/players/w/whitfdw01.html
# https://www.basketball-reference.com/players/w/whitnch01.html
# https://www.basketball-reference.com/players/w/whitnha01.html
# https://www.basketball-reference.com/players/w/whitnha02.html
# https://www.basketball-reference.com/players/w/whittsh01.html
# https://www.basketball-reference.com/players/w/wickssi01.html
# https://www.basketball-reference.com/players/w/widbyro01.html
# https://www.basketball-reference.com/players/w/wiermu01.html
# https://www.basketball-reference.com/players/w/wiesebo01.html
# https://www.basketball-reference.com/players/w/wiggian01.html
# https://www.basketball-reference.com/players/w/wiggimi01.html
# https://www.basketball-reference.com/players/w/wilbuke01.html
# https://www.basketball-reference.com/players/w/wilcocj01.html
# https://www.basketball-reference.com/players/w/wilcoch01.html
# https://www.basketball-reference.com/players/w/wilcudc01.html
# https://www.basketball-reference.com/players/w/wileyge01.html
# https://www.basketball-reference.com/players/w/wileymi01.html
# https://www.basketball-reference.com/players/w/wileymo01.html
# https://www.basketball-reference.com/players/w/wilfowi01.html
# https://www.basketball-reference.com/players/w/wilkele01.html
# https://www.basketball-reference.com/players/w/wilkebo01.html
# https://www.basketball-reference.com/players/w/wilkeja01.html
# https://www.basketball-reference.com/players/w/wilkeja02.html
# https://www.basketball-reference.com/players/w/wilkida02.html
# https://www.basketball-reference.com/players/w/wilkido01.html
# https://www.basketball-reference.com/players/w/wilkied01.html
# https://www.basketball-reference.com/players/w/wilkige01.html
# https://www.basketball-reference.com/players/w/wilkije01.html
# https://www.basketball-reference.com/players/w/wilkida01.html
# https://www.basketball-reference.com/players/w/wilksmi01.html
# https://www.basketball-reference.com/players/w/williaa01.html
# https://www.basketball-reference.com/players/w/willial01.html
# https://www.basketball-reference.com/players/w/willial03.html
# https://www.basketball-reference.com/players/w/willial02.html
# https://www.basketball-reference.com/players/w/williar01.html
# https://www.basketball-reference.com/players/w/willibe01.html
# https://www.basketball-reference.com/players/w/willibo01.html
# https://www.basketball-reference.com/players/w/willibr01.html
# https://www.basketball-reference.com/players/w/willibu01.html
# https://www.basketball-reference.com/players/w/willich01.html
# https://www.basketball-reference.com/players/w/willich02.html
# https://www.basketball-reference.com/players/w/willich03.html
# https://www.basketball-reference.com/players/w/willicl01.html
# https://www.basketball-reference.com/players/w/willico01.html
# https://www.basketball-reference.com/players/w/willide01.html
# https://www.basketball-reference.com/players/w/willide02.html
# https://www.basketball-reference.com/players/w/willidu01.html
# https://www.basketball-reference.com/players/w/williea01.html
# https://www.basketball-reference.com/players/w/williel01.html
# https://www.basketball-reference.com/players/w/willier01.html
# https://www.basketball-reference.com/players/w/willifl01.html
# https://www.basketball-reference.com/players/w/willifr02.html
# https://www.basketball-reference.com/players/w/willifr01.html
# https://www.basketball-reference.com/players/w/willige01.html
# https://www.basketball-reference.com/players/w/willigu01.html
# https://www.basketball-reference.com/players/w/willigu02.html
# https://www.basketball-reference.com/players/w/williha01.html
# https://www.basketball-reference.com/players/w/willihe01.html
# https://www.basketball-reference.com/players/w/williho01.html
# https://www.basketball-reference.com/players/w/willija02.html
# https://www.basketball-reference.com/players/w/willija04.html
# https://www.basketball-reference.com/players/w/willija03.html
# https://www.basketball-reference.com/players/w/willija01.html
# https://www.basketball-reference.com/players/w/willije01.html
# https://www.basketball-reference.com/players/w/willijo02.html
# https://www.basketball-reference.com/players/w/willijo03.html
# https://www.basketball-reference.com/players/w/williju01.html
# https://www.basketball-reference.com/players/w/willike03.html
# https://www.basketball-reference.com/players/w/willike01.html
# https://www.basketball-reference.com/players/w/willilo01.html
# https://www.basketball-reference.com/players/w/willilo02.html
# https://www.basketball-reference.com/players/w/willima03.html
# https://www.basketball-reference.com/players/w/willima04.html
# https://www.basketball-reference.com/players/w/willima02.html
# https://www.basketball-reference.com/players/w/willimi02.html
# https://www.basketball-reference.com/players/w/willimi03.html
# https://www.basketball-reference.com/players/w/willimi01.html
# https://www.basketball-reference.com/players/w/willima01.html
# https://www.basketball-reference.com/players/w/willimo01.html
# https://www.basketball-reference.com/players/w/willina01.html
# https://www.basketball-reference.com/players/w/willipe01.html
# https://www.basketball-reference.com/players/w/willira01.html
# https://www.basketball-reference.com/players/w/willire01.html
# https://www.basketball-reference.com/players/w/willire02.html
# https://www.basketball-reference.com/players/w/williri01.html
# https://www.basketball-reference.com/players/w/williro02.html
# https://www.basketball-reference.com/players/w/williro01.html
# https://www.basketball-reference.com/players/w/willisa01.html
# https://www.basketball-reference.com/players/w/willisa02.html
# https://www.basketball-reference.com/players/w/willisc01.html
# https://www.basketball-reference.com/players/w/willise01.html
# https://www.basketball-reference.com/players/w/willish01.html
# https://www.basketball-reference.com/players/w/willish03.html
# https://www.basketball-reference.com/players/w/willish02.html
# https://www.basketball-reference.com/players/w/willisl01.html
# https://www.basketball-reference.com/players/w/willite01.html
# https://www.basketball-reference.com/players/w/willitr01.html
# https://www.basketball-reference.com/players/w/willitr02.html
# https://www.basketball-reference.com/players/w/williwa02.html
# https://www.basketball-reference.com/players/w/williwa01.html
# https://www.basketball-reference.com/players/w/williwi01.html
# https://www.basketball-reference.com/players/w/willico02.html
# https://www.basketball-reference.com/players/w/willijo01.html
# https://www.basketball-reference.com/players/w/williva01.html
# https://www.basketball-reference.com/players/w/willike02.html
# https://www.basketball-reference.com/players/w/willobi01.html
# https://www.basketball-reference.com/players/w/willode01.html
# https://www.basketball-reference.com/players/w/wilsobo01.html
# https://www.basketball-reference.com/players/w/wilsobo02.html
# https://www.basketball-reference.com/players/w/wilsobo03.html
# https://www.basketball-reference.com/players/w/wilsobu01.html
# https://www.basketball-reference.com/players/w/wilsoge01.html
# https://www.basketball-reference.com/players/w/wilsois01.html
# https://www.basketball-reference.com/players/w/wilsoja01.html
# https://www.basketball-reference.com/players/w/wilsoji01.html
# https://www.basketball-reference.com/players/w/wilsomi01.html
# https://www.basketball-reference.com/players/w/wilsoni01.html
# https://www.basketball-reference.com/players/w/wilsoot01.html
# https://www.basketball-reference.com/players/w/wilsori01.html
# https://www.basketball-reference.com/players/w/wilsori02.html
# https://www.basketball-reference.com/players/w/wilsost01.html
# https://www.basketball-reference.com/players/w/wilsotr01.html
# https://www.basketball-reference.com/players/w/wiltjky01.html
# https://www.basketball-reference.com/players/w/winchke01.html
# https://www.basketball-reference.com/players/w/windito01.html
# https://www.basketball-reference.com/players/w/windsjo01.html
# https://www.basketball-reference.com/players/w/winfile01.html
# https://www.basketball-reference.com/players/w/wingada01.html
# https://www.basketball-reference.com/players/w/wingfdo01.html
# https://www.basketball-reference.com/players/w/wingoha01.html
# https://www.basketball-reference.com/players/w/winklma01.html
# https://www.basketball-reference.com/players/w/winslju01.html
# https://www.basketball-reference.com/players/w/winslri01.html
# https://www.basketball-reference.com/players/w/wintetr01.html
# https://www.basketball-reference.com/players/w/wintebr01.html
# https://www.basketball-reference.com/players/w/wintevo01.html
# https://www.basketball-reference.com/players/w/wisesk01.html
# https://www.basketball-reference.com/players/w/wisewi01.html
# https://www.basketball-reference.com/players/w/witheje01.html
# https://www.basketball-reference.com/players/w/wittelu01.html
# https://www.basketball-reference.com/players/w/wittmgr01.html
# https://www.basketball-reference.com/players/w/wittmra01.html
# https://www.basketball-reference.com/players/w/wittsga01.html
# https://www.basketball-reference.com/players/w/wohlda01.html
# https://www.basketball-reference.com/players/w/wolfjo01.html
# https://www.basketball-reference.com/players/w/wolkoru01.html
# https://www.basketball-reference.com/players/w/woltena01.html
# https://www.basketball-reference.com/players/w/woodal01.html
# https://www.basketball-reference.com/players/w/woodbo01.html
# https://www.basketball-reference.com/players/w/woodch01.html
# https://www.basketball-reference.com/players/w/woodda01.html
# https://www.basketball-reference.com/players/w/woodho01.html
# https://www.basketball-reference.com/players/w/woodle01.html
# https://www.basketball-reference.com/players/w/woodslo01.html
# https://www.basketball-reference.com/players/w/woodsqy01.html
# https://www.basketball-reference.com/players/w/woodsra01.html
# https://www.basketball-reference.com/players/w/woodsto01.html
# https://www.basketball-reference.com/players/w/woodsmi01.html
# https://www.basketball-reference.com/players/w/woollbo01.html
# https://www.basketball-reference.com/players/w/woolror01.html
# https://www.basketball-reference.com/players/w/workmha01.html
# https://www.basketball-reference.com/players/w/workmma01.html
# https://www.basketball-reference.com/players/w/workmto01.html
# https://www.basketball-reference.com/players/a/artesro01.html
# https://www.basketball-reference.com/players/w/worslwi01.html
# https://www.basketball-reference.com/players/w/worthsa01.html
# https://www.basketball-reference.com/players/w/worthja01.html
# https://www.basketball-reference.com/players/w/wrighan01.html
# https://www.basketball-reference.com/players/w/wrighbr02.html
# https://www.basketball-reference.com/players/w/wrighbr01.html
# https://www.basketball-reference.com/players/w/wrighbr03.html
# https://www.basketball-reference.com/players/w/wrighch01.html
# https://www.basketball-reference.com/players/w/wrighch02.html
# https://www.basketball-reference.com/players/w/wrighde01.html
# https://www.basketball-reference.com/players/w/wrighdo01.html
# https://www.basketball-reference.com/players/w/wrighho02.html
# https://www.basketball-reference.com/players/w/wrighho01.html
# https://www.basketball-reference.com/players/w/wrighjo01.html
# https://www.basketball-reference.com/players/w/wrighju01.html
# https://www.basketball-reference.com/players/w/wrighla01.html
# https://www.basketball-reference.com/players/w/wrighle01.html
# https://www.basketball-reference.com/players/w/wrighlo01.html
# https://www.basketball-reference.com/players/w/wrighlo02.html
# https://www.basketball-reference.com/players/w/wrighlu01.html
# https://www.basketball-reference.com/players/w/wrighsh01.html
# https://www.basketball-reference.com/players/w/wroteto01.html
# https://www.basketball-reference.com/players/w/wuycide01.html
# https://www.basketball-reference.com/players/w/wyndeaj01.html
# https://www.basketball-reference.com/players/y/yarbrvi01.html
# https://www.basketball-reference.com/players/y/yardlge01.html
# https://www.basketball-reference.com/players/y/yatesba01.html
# https://www.basketball-reference.com/players/y/yateswa01.html
# https://www.basketball-reference.com/players/y/yelvech01.html
# https://www.basketball-reference.com/players/y/yonakri01.html
# https://www.basketball-reference.com/players/y/youngda01.html
# https://www.basketball-reference.com/players/y/youngja01.html
# https://www.basketball-reference.com/players/y/youngjo01.html
# https://www.basketball-reference.com/players/y/youngko01.html
# https://www.basketball-reference.com/players/y/youngmi01.html
# https://www.basketball-reference.com/players/y/youngni01.html
# https://www.basketball-reference.com/players/y/youngpe01.html
# https://www.basketball-reference.com/players/y/youngsa01.html
# https://www.basketball-reference.com/players/y/youngth01.html
# https://www.basketball-reference.com/players/y/youngti01.html
# https://www.basketball-reference.com/players/y/yuesu01.html
# https://www.basketball-reference.com/players/z/zasloma01.html
# https://www.basketball-reference.com/players/z/zawolze01.html
# https://www.basketball-reference.com/players/z/zelleco01.html
# https://www.basketball-reference.com/players/z/zelleda01.html
# https://www.basketball-reference.com/players/z/zellega01.html
# https://www.basketball-reference.com/players/z/zelleha01.html
# https://www.basketball-reference.com/players/z/zellelu01.html
# https://www.basketball-reference.com/players/z/zellety01.html
# https://www.basketball-reference.com/players/z/zenoto01.html
# https://www.basketball-reference.com/players/z/zevenph01.html
# https://www.basketball-reference.com/players/z/zhizhwa01.html
# https://www.basketball-reference.com/players/z/zidekge01.html
# https://www.basketball-reference.com/players/z/zimmede01.html
# https://www.basketball-reference.com/players/z/zimmest01.html
# https://www.basketball-reference.com/players/z/zipsepa01.html
# https://www.basketball-reference.com/players/z/zoetji01.html
# https://www.basketball-reference.com/players/z/zopfbi01.html
# https://www.basketball-reference.com/players/z/zubaciv01.html
# https://www.basketball-reference.com/players/z/zunicma01.html

# %%
# let's see if there is any missing data
player_df_copy = player_df.replace("", np.NaN)
import missingno as msno

# Nullity or missing values by columns
msno.matrix(df=player_df_copy.iloc[:,:],figsize=(20, 14), color=(0.42, 0.1, 0.05))

# %%
player_df[player_df['Wt'] == ""]
# Out:
#                Player BR_player_id  From    To Pos    Ht Wt  \
# 2097      George Karl     karlge01  1974  1978
# 2310         Dick Lee      leedi01  1968  1968   F   6-6
# 2725  Murray Mitchell    mitchmu01  1950  1950   C   6-6
# 2911       Paul Nolen    nolenpa01  1954  1954   C  6-10
# 4197       Ray Wertis    wertira01  1947  1948   G  5-11
# 4384         Bob Wood     woodbo01  1950  1950   G  5-10
#
#              Birth Date                       College active shoots  \
# 2097       May 12, 1952  University of North Carolina      0    NaN
# 2310                         University of Washington      0  Right
# 2725     March 19, 1923  Sam Houston State University      0  Right
# 2911  September 3, 1929         Texas Tech University      0  Right
# 4197    January 1, 1922         St. John's University      0  Right
# 4384    October 7, 1921  Northern Illinois University      0  Right
#
#              draft_team                          pick_order draft_year_type
# 2097    New York Knicks  4th round (14th pick,66th overall)  1973 NBA Draft
# 2310                NaN                                 NaN             NaN
# 2725     Boston Celtics                                 NaN             NaN
# 2911  Baltimore Bullets                                 NaN             NaN
# 4197                NaN                                 NaN             NaN
# 4384                NaN                                 NaN             NaN

# %%
def _get_the_soup(BR_player_id):
    url = "https://www.basketball-reference.com/players/"+BR_player_id[0]+"/"+BR_player_id+".html"
    html = urlopen(url)
    
    return BeautifulSoup(html,'lxml')

def _get_player_div_tags(BR_player_id):
    soup = _get_the_soup(BR_player_id)

    div_tags = [entry.get("id") for entry in soup.find_all('div') if entry.get("id") is not None]

    possible_tags = []
    for tag in div_tags:
        if re.match('all',tag):
            if re.search(r"\d",tag):
                continue
            if tag == "all_per_game":
                continue
            possible_tags.append(tag)
    
    return possible_tags

def create_player_df_per_game(BR_player_id):
    
    soup = _get_the_soup(BR_player_id)
    
    div_tag = "all_per_game"
    div_HTML = soup.find("div", {"id": div_tag})
    table_header = div_HTML.find('thead')
    table_body = div_HTML.find('tbody')
    col_headers = [info.getText().strip() for info in table_header.find_all('tr')]

    # returns a string for some reason, there must be a better way but this works
    col_headers = [val for val in col_headers[0].split()]
    df_all_per_game = pd.DataFrame(columns=col_headers)

    for i,row in enumerate(table_body.find_all('tr')):
        fill_vals = [row.find('th').text] + [val.text for val in row.find_all('td')]
        df_all_per_game.loc[i] = fill_vals 

    return df_all_per_game

def create_player_df_table(div_tag,BR_player_id):
    soup = _get_the_soup(BR_player_id)

    # parse via div_tags
    div_HTML = soup.find("div", {"id": div_tag})

    # sometimes data are in comments
    try:
        comments = div_HTML.findAll(text=lambda text:isinstance(text, Comment))
        div_soup = BeautifulSoup(comments[0],'lxml')
    except AttributeError:
        div_soup = div_HTML
        

    # to get table headers isolate thead
    table_header = div_soup.find('thead')
    
    table_body = div_soup.find('tbody')

    col_headers = [info.getText().strip() for info in table_header.find_all('tr')][0].split("\n")
    try:
        empty_header = [col_headers.index("")]
        for index in empty_header:
            del col_headers[index]
    except ValueError:
        empty_header = []
        
    df_all_totals = pd.DataFrame(columns=col_headers)
    for i,row in enumerate(table_body.find_all('tr')):
        fill_vals = [row.find('th').text] + [val.text for val in row.find_all('td')]
        
        if len(empty_header) > 0:
            for index in empty_header:
                del fill_vals[index]
        
        df_all_totals.loc[i] = fill_vals 
    
    return df_all_totals

# %%
BR_player_id = 'abdulta01'

# To-do: more advanced tables later.
possible_tags = ['all_totals','all_per_minute','all_per_poss','all_advanced']

#BR_player_id = 'acresma01'
df = create_player_df_per_game(BR_player_id)
# for tag in possible_tags:
#     print(tag)
#     df = create_player_df_table(str(tag),BR_player_id)
#     #print(df)

# %%
# for all per game players 

df_per_game_all = pd.DataFrame()

for player in player_df['BR_player_id'].unique():
    df_player = create_player_df_per_game(BR_player_id)
    df_player = df_player.assign(BR_player_id=[player]*len(df_player))
    
    if len(df_per_game_all.columns) == 0:
        df_per_game_all.rename(columns = df_player.columns.values.tolist() + ['BR_player_id'])
        
    df_per_game_all = df_per_game_all.append(df_player)

# possible_tags = ['all_totals','all_per_minute','all_per_poss','all_advanced']

#     for tag in possible_tags:
#         print(tag)
#         df = create_player_df_table(str(tag),BR_player_id)
#         #print(df)

# %%
possible_tags = ['all_per_poss','all_advanced']#,'all_totals','all_per_minute',]

for tag in possible_tags:
    df_all = pd.DataFrame()
    print(tag)
    for player in player_df['BR_player_id'].unique():
        df_player = create_player_df_table(str(tag),BR_player_id)
        df_player = df_player.assign(BR_player_id=[player]*len(df_player))

        if len(df_all.columns) == 0:
            df_all.rename(columns = df_player.columns.values.tolist() + ['BR_player_id'])

        df_all = df_per_game_all.append(df_player)
    df_all.to_csv(tag+'_all_players.csv')
        #print(df)
# Out:
# all_per_minute
# all_per_poss

# %%
df_per_game_all.to_csv('all_players_per_game.csv')
